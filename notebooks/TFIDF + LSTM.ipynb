# %%
# !pip install scikit-multilearn
# Out:
# Collecting scikit-multilearn
#   Downloading https://files.pythonhosted.org/packages/bb/1f/e6ff649c72a1cdf2c7a1d31eb21705110ce1c5d3e7e26b2cc300e1637272/scikit_multilearn-0.2.0-py3-none-any.whl (89kB)
#      |████████████████████████████████| 92kB 2.3MB/s
# Installing collected packages: scikit-multilearn
# Successfully installed scikit-multilearn-0.2.0

# %%
import pandas as pd
import matplotlib as plt
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split


import pickle
from scipy.sparse import hstack
from skmultilearn.model_selection import iterative_train_test_split

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
dir = "drive/My Drive/BT4221/Data/"
df = pd.read_csv(dir+"cleaned_train_v1.csv")
df = df.drop('Unnamed: 0', 1)
df.head()
# Out:
#                  id  ... subjectivity
# 0  0000997932d777bf  ...     0.262369
# 1  000103f0d9cfb60f  ...    -0.674041
# 2  000113f07ec002fd  ...     0.000397
# 3  0001b41b1c6bb37e  ...    -0.316384
# 4  0001d958c54c6e35  ...    -1.409792
#
# [5 rows x 23 columns]

# %%
X = df['processed_text']
y = df[["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]].values
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size = 0.2, random_state=1234)

# %%
tf = TfidfVectorizer()

tf_train = tf.fit_transform(X_train).todense()
tf_test = tf.transform(X_test).todense()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b144a1efae77> in <module>()
# ----> 1 tf = TfidfVectorizer()
#       2
#       3 tf_train = tf.fit_transform(X_train).todense()
#       4 tf_test = tf.transform(X_test).todense()
#
# NameError: name 'TfidfVectorizer' is not defined
